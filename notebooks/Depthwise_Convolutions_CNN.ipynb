# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import datasets, layers, models
from keras.models import Sequential, Model
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense, Dropout
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import os
import sys
import datetime
from keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import pandas as pd

# %%
# %load_ext tensorboard

# %%
def load_dataset():
    # load cifar10 dataset
    (trainX, trainy), (testX, testy)  = datasets.cifar10.load_data()
    # summarize loaded dataset
    print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
    print('Test: X=%s, y=%s' % (testX.shape, testy.shape))
     # one hot encode target values
    trainY = to_categorical(trainy)
    testY = to_categorical(testy)
    return trainX, trainY, testX, testY

# %%
# scale pixels
def prep_pixels(train, test):
    # convert from integers to floats
    train_norm = train.astype('float32')
    test_norm = test.astype('float32')
    # normalize to range 0-1
    train_norm = train_norm / 255.0
    test_norm = test_norm / 255.0
    # return normalized images
    return train_norm, test_norm

# %%
def separable_conv(i, ch):
    x = layers.DepthwiseConv2D((3,3), padding="same")(i)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(ch, (1,1), padding="same")(x)
    x = layers.BatchNormalization()(x)
    return layers.Activation("relu")(x)

# %%
def define_model():
    input = layers.Input((32,32,3))
    x = layers.Conv2D(16, (3, 3), padding='same')(input)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = separable_conv(x, 24)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 48)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 96)
    x = separable_conv(x, 192)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 96)
    x = separable_conv(x, 192)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dense(500, activation='relu')(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(10, activation='softmax')(x)
    model = Model(input, x)
    # compile model
    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    print(model.summary())

    return model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history, file):
    # plot loss
    plt.subplot(211)
    plt.title('Cross Entropy Loss')
    plt.plot(history.history['loss'], color='blue', label='train')
    plt.plot(history.history['val_loss'], color='orange', label='test')
    # plot accuracy
    plt.subplot(212)
    plt.title('Classification Accuracy')
    plt.plot(history.history['accuracy'], color='blue', label='train')
    plt.plot(history.history['val_accuracy'], color='orange', label='test')
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    plt.savefig(r"../logs/" + filename + file)
    plt.close()

# %%
def train_steps():
    # load dataset
    trainX, trainY, testX, testY = load_dataset()
    # prepare pixel data
    trainX, testX = prep_pixels(trainX, testX)
    # define model
    model = define_model()
    #ensures that logs are created and stored.
    #remove any previous logs
    print(model.summary())
    # %rm -rf ./logs/
    log_dir = "../logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

    # We'll stop training if no improvement after some epochs
    earlystopper = EarlyStopping(monitor='val_accuracy', patience=8, verbose=1)
    reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=8, 
                                   verbose=1, mode='max', min_lr=0.00001)
    # fit model
    history = model.fit(trainX, trainY, epochs=100, batch_size=48, validation_split=0.20, callbacks=[earlystopper, reduce_lr, tensorboard_callback], verbose=1)
    print(model.summary())
    # evaluate model
    _, acc = model.evaluate(testX, testY, verbose=0)
    print('> %.3f' % (acc * 100.0))
    # learning curves
    summarize_diagnostics(history, 'ipykernel_launcher.py3blocks_depthconv_ver2.png')

    return model, testX, testY

# %%
model, testX, testY = train_steps()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.SGD`.
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_93 (Conv2D)          (None, 32, 32, 16)        448
#
#  batch_normalization_124 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 32, 32, 16)        0
#
#  depthwise_conv2d_49 (Depth  (None, 32, 32, 16)        160
#  wiseConv2D)
#
#  batch_normalization_125 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 32, 32, 16)        0
#
#  conv2d_94 (Conv2D)          (None, 32, 32, 24)        408
#
#  batch_normalization_126 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_100 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_50 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_127 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_101 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_95 (Conv2D)          (None, 16, 16, 48)        1200
#
#  batch_normalization_128 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_102 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_40 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_51 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_129 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_103 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 96)          4704
#
#  batch_normalization_130 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_104 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_52 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_131 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_105 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 192)         18624
#
#  batch_normalization_132 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_106 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_41 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_53 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_133 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_107 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_98 (Conv2D)          (None, 4, 4, 96)          18528
#
#  batch_normalization_134 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_108 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_54 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_135 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_109 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_99 (Conv2D)          (None, 4, 4, 192)         18624
#
#  batch_normalization_136 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_110 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_42 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  dense_10 (Dense)            (None, 2, 2, 500)         96500
#
#  flatten_8 (Flatten)         (None, 2000)              0
#
#  dropout_10 (Dropout)        (None, 2000)              0
#
#  dense_11 (Dense)            (None, 10)                20010
#
# =================================================================
# Total params: 188310 (735.59 KB)
# Trainable params: 186038 (726.71 KB)
# Non-trainable params: 2272 (8.88 KB)
# _________________________________________________________________
# None
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_93 (Conv2D)          (None, 32, 32, 16)        448
#
#  batch_normalization_124 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 32, 32, 16)        0
#
#  depthwise_conv2d_49 (Depth  (None, 32, 32, 16)        160
#  wiseConv2D)
#
#  batch_normalization_125 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 32, 32, 16)        0
#
#  conv2d_94 (Conv2D)          (None, 32, 32, 24)        408
#
#  batch_normalization_126 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_100 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_50 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_127 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_101 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_95 (Conv2D)          (None, 16, 16, 48)        1200
#
#  batch_normalization_128 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_102 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_40 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_51 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_129 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_103 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 96)          4704
#
#  batch_normalization_130 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_104 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_52 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_131 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_105 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 192)         18624
#
#  batch_normalization_132 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_106 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_41 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_53 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_133 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_107 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_98 (Conv2D)          (None, 4, 4, 96)          18528
#
#  batch_normalization_134 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_108 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_54 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_135 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_109 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_99 (Conv2D)          (None, 4, 4, 192)         18624
#
#  batch_normalization_136 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_110 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_42 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  dense_10 (Dense)            (None, 2, 2, 500)         96500
#
#  flatten_8 (Flatten)         (None, 2000)              0
#
#  dropout_10 (Dropout)        (None, 2000)              0
#
#  dense_11 (Dense)            (None, 10)                20010
#
# =================================================================
# Total params: 188310 (735.59 KB)
# Trainable params: 186038 (726.71 KB)
# Non-trainable params: 2272 (8.88 KB)
# _________________________________________________________________
# None
# Epoch 1/100
# 834/834 [==============================] - 30s 35ms/step - loss: 1.7471 - accuracy: 0.3529 - val_loss: 1.5647 - val_accuracy: 0.4183 - lr: 0.0010
# Epoch 2/100
# 834/834 [==============================] - 29s 35ms/step - loss: 1.4402 - accuracy: 0.4722 - val_loss: 1.4834 - val_accuracy: 0.4780 - lr: 0.0010
# Epoch 3/100
# 834/834 [==============================] - 28s 34ms/step - loss: 1.3196 - accuracy: 0.5218 - val_loss: 1.4003 - val_accuracy: 0.4971 - lr: 0.0010
# Epoch 4/100
# 834/834 [==============================] - 29s 34ms/step - loss: 1.2241 - accuracy: 0.5612 - val_loss: 1.2896 - val_accuracy: 0.5491 - lr: 0.0010
# Epoch 5/100
# 834/834 [==============================] - 29s 35ms/step - loss: 1.1494 - accuracy: 0.5866 - val_loss: 1.3193 - val_accuracy: 0.5320 - lr: 0.0010
# Epoch 6/100
# 834/834 [==============================] - 29s 35ms/step - loss: 1.0879 - accuracy: 0.6093 - val_loss: 1.2096 - val_accuracy: 0.5733 - lr: 0.0010
# Epoch 7/100
# 834/834 [==============================] - 29s 35ms/step - loss: 1.0298 - accuracy: 0.6322 - val_loss: 1.2173 - val_accuracy: 0.5641 - lr: 0.0010
# Epoch 8/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.9825 - accuracy: 0.6518 - val_loss: 1.1112 - val_accuracy: 0.6073 - lr: 0.0010
# Epoch 9/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.9381 - accuracy: 0.6654 - val_loss: 1.1158 - val_accuracy: 0.6132 - lr: 0.0010
# Epoch 10/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.8931 - accuracy: 0.6838 - val_loss: 1.1545 - val_accuracy: 0.5948 - lr: 0.0010
# Epoch 11/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.8599 - accuracy: 0.6973 - val_loss: 1.0752 - val_accuracy: 0.6223 - lr: 0.0010
# Epoch 12/100
# 834/834 [==============================] - 28s 34ms/step - loss: 0.8288 - accuracy: 0.7071 - val_loss: 1.0128 - val_accuracy: 0.6486 - lr: 0.0010
# Epoch 13/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.7963 - accuracy: 0.7176 - val_loss: 1.0196 - val_accuracy: 0.6514 - lr: 0.0010
# Epoch 14/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.7639 - accuracy: 0.7295 - val_loss: 1.0911 - val_accuracy: 0.6253 - lr: 0.0010
# Epoch 15/100
# 834/834 [==============================] - 30s 35ms/step - loss: 0.7341 - accuracy: 0.7389 - val_loss: 1.0132 - val_accuracy: 0.6553 - lr: 0.0010
# Epoch 16/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.7138 - accuracy: 0.7468 - val_loss: 1.0092 - val_accuracy: 0.6558 - lr: 0.0010
# Epoch 17/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.6850 - accuracy: 0.7581 - val_loss: 1.0000 - val_accuracy: 0.6581 - lr: 0.0010
# Epoch 18/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.6644 - accuracy: 0.7642 - val_loss: 0.9960 - val_accuracy: 0.6584 - lr: 0.0010
# Epoch 19/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.6431 - accuracy: 0.7733 - val_loss: 0.9187 - val_accuracy: 0.6882 - lr: 0.0010
# Epoch 20/100
# 834/834 [==============================] - 28s 34ms/step - loss: 0.6180 - accuracy: 0.7826 - val_loss: 0.9782 - val_accuracy: 0.6718 - lr: 0.0010
# Epoch 21/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.5970 - accuracy: 0.7874 - val_loss: 0.9516 - val_accuracy: 0.6858 - lr: 0.0010
# Epoch 22/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.5801 - accuracy: 0.7942 - val_loss: 1.0199 - val_accuracy: 0.6647 - lr: 0.0010
# Epoch 23/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.5583 - accuracy: 0.8020 - val_loss: 0.9660 - val_accuracy: 0.6730 - lr: 0.0010
# Epoch 24/100
# 834/834 [==============================] - 29s 35ms/step - loss: 0.5372 - accuracy: 0.8114 - val_loss: 1.0074 - val_accuracy: 0.6731 - lr: 0.0010
# Epoch 25/100
# 834/834 [==============================] - 29s 34ms/step - loss: 0.5193 - accuracy: 0.8163 - val_loss: 1.0426 - val_accuracy: 0.6624 - lr: 0.0010
# Epoch 26/100
# 834/834 [==============================] - 30s 35ms/step - loss: 0.5088 - accuracy: 0.8198 - val_loss: 1.0010 - val_accuracy: 0.6814 - lr: 0.0010
# Epoch 27/100
# 833/834 [============================>.] - ETA: 0s - loss: 0.4848 - accuracy: 0.8288
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 834/834 [==============================] - 29s 34ms/step - loss: 0.4848 - accuracy: 0.8288 - val_loss: 0.9603 - val_accuracy: 0.6868 - lr: 0.0010
# Epoch 27: early stopping
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_93 (Conv2D)          (None, 32, 32, 16)        448
#
#  batch_normalization_124 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 32, 32, 16)        0
#
#  depthwise_conv2d_49 (Depth  (None, 32, 32, 16)        160
#  wiseConv2D)
#
#  batch_normalization_125 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 32, 32, 16)        0
#
#  conv2d_94 (Conv2D)          (None, 32, 32, 24)        408
#
#  batch_normalization_126 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_100 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_50 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_127 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_101 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_95 (Conv2D)          (None, 16, 16, 48)        1200
#
#  batch_normalization_128 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_102 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_40 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_51 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_129 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_103 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 96)          4704
#
#  batch_normalization_130 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_104 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_52 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_131 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_105 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 192)         18624
#
#  batch_normalization_132 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_106 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_41 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_53 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_133 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_107 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_98 (Conv2D)          (None, 4, 4, 96)          18528
#
#  batch_normalization_134 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_108 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_54 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_135 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_109 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_99 (Conv2D)          (None, 4, 4, 192)         18624
#
#  batch_normalization_136 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_110 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_42 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  dense_10 (Dense)            (None, 2, 2, 500)         96500
#
#  flatten_8 (Flatten)         (None, 2000)              0
#
#  dropout_10 (Dropout)        (None, 2000)              0
#
#  dense_11 (Dense)            (None, 10)                20010
#
# =================================================================
# Total params: 188310 (735.59 KB)
# Trainable params: 186038 (726.71 KB)
# Non-trainable params: 2272 (8.88 KB)
# _________________________________________________________________
# None
# > 69.100

# %%
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_93 (Conv2D)          (None, 32, 32, 16)        448
#
#  batch_normalization_124 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 32, 32, 16)        0
#
#  depthwise_conv2d_49 (Depth  (None, 32, 32, 16)        160
#  wiseConv2D)
#
#  batch_normalization_125 (B  (None, 32, 32, 16)        64
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 32, 32, 16)        0
#
#  conv2d_94 (Conv2D)          (None, 32, 32, 24)        408
#
#  batch_normalization_126 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_100 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_50 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_127 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_101 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_95 (Conv2D)          (None, 16, 16, 48)        1200
#
#  batch_normalization_128 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_102 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_40 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_51 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_129 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_103 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_96 (Conv2D)          (None, 8, 8, 96)          4704
#
#  batch_normalization_130 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_104 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_52 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_131 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_105 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_97 (Conv2D)          (None, 8, 8, 192)         18624
#
#  batch_normalization_132 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_106 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_41 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_53 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_133 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_107 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_98 (Conv2D)          (None, 4, 4, 96)          18528
#
#  batch_normalization_134 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_108 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_54 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_135 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_109 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_99 (Conv2D)          (None, 4, 4, 192)         18624
#
#  batch_normalization_136 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_110 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_42 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  dense_10 (Dense)            (None, 2, 2, 500)         96500
#
#  flatten_8 (Flatten)         (None, 2000)              0
#
#  dropout_10 (Dropout)        (None, 2000)              0
#
#  dense_11 (Dense)            (None, 10)                20010
#
# =================================================================
# Total params: 188310 (735.59 KB)
# Trainable params: 186038 (726.71 KB)
# Non-trainable params: 2272 (8.88 KB)
# _________________________________________________________________

# %%
def define_model():
    input = layers.Input((32,32,3))
    x = layers.Conv2D(32, (3, 3), padding='same')(input)
    x = layers.Conv2D(64, (3, 3), padding='same')(x)
    x = layers.Conv2D(128, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = separable_conv(x, 24)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 48)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 96)
    x = separable_conv(x, 192)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 96)
    x = separable_conv(x, 192)
    x = layers.MaxPooling2D((2, 2))(x)
    x = separable_conv(x, 96)
    x = separable_conv(x, 192)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.Dense(500, activation='relu')(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Dense(10, activation='softmax')(x)
    model = Model(input, x)
    # compile model
    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    print(model.summary())

    return model

# %%
model, testX, testY = train_steps()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.SGD`.
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_100 (Conv2D)         (None, 32, 32, 32)        896
#
#  conv2d_101 (Conv2D)         (None, 32, 32, 64)        18496
#
#  conv2d_102 (Conv2D)         (None, 32, 32, 128)       73856
#
#  batch_normalization_137 (B  (None, 32, 32, 128)       512
#  atchNormalization)
#
#  activation_111 (Activation  (None, 32, 32, 128)       0
#  )
#
#  depthwise_conv2d_55 (Depth  (None, 32, 32, 128)       1280
#  wiseConv2D)
#
#  batch_normalization_138 (B  (None, 32, 32, 128)       512
#  atchNormalization)
#
#  activation_112 (Activation  (None, 32, 32, 128)       0
#  )
#
#  conv2d_103 (Conv2D)         (None, 32, 32, 24)        3096
#
#  batch_normalization_139 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_113 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_43 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_56 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_140 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_114 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_104 (Conv2D)         (None, 16, 16, 48)        1200
#
#  batch_normalization_141 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_115 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_44 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_57 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_142 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_116 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_105 (Conv2D)         (None, 8, 8, 96)          4704
#
#  batch_normalization_143 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_117 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_58 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_144 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_118 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_106 (Conv2D)         (None, 8, 8, 192)         18624
#
#  batch_normalization_145 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_119 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_45 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_59 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_146 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_120 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_107 (Conv2D)         (None, 4, 4, 96)          18528
#
#  batch_normalization_147 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_121 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_60 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_148 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_122 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_108 (Conv2D)         (None, 4, 4, 192)         18624
#
#  batch_normalization_149 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_123 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_46 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  depthwise_conv2d_61 (Depth  (None, 2, 2, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_150 (B  (None, 2, 2, 192)         768
#  atchNormalization)
#
#  activation_124 (Activation  (None, 2, 2, 192)         0
#  )
#
#  conv2d_109 (Conv2D)         (None, 2, 2, 96)          18528
#
#  batch_normalization_151 (B  (None, 2, 2, 96)          384
#  atchNormalization)
#
#  activation_125 (Activation  (None, 2, 2, 96)          0
#  )
#
#  depthwise_conv2d_62 (Depth  (None, 2, 2, 96)          960
#  wiseConv2D)
#
#  batch_normalization_152 (B  (None, 2, 2, 96)          384
#  atchNormalization)
#
#  activation_126 (Activation  (None, 2, 2, 96)          0
#  )
#
#  conv2d_110 (Conv2D)         (None, 2, 2, 192)         18624
#
#  batch_normalization_153 (B  (None, 2, 2, 192)         768
#  atchNormalization)
#
#  activation_127 (Activation  (None, 2, 2, 192)         0
#  )
#
#  max_pooling2d_47 (MaxPooli  (None, 1, 1, 192)         0
#  ng2D)
#
#  dense_12 (Dense)            (None, 1, 1, 500)         96500
#
#  flatten_9 (Flatten)         (None, 500)               0
#
#  dropout_11 (Dropout)        (None, 500)               0
#
#  dense_13 (Dense)            (None, 10)                5010
#
# =================================================================
# Total params: 313150 (1.19 MB)
# Trainable params: 309278 (1.18 MB)
# Non-trainable params: 3872 (15.12 KB)
# _________________________________________________________________
# None
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_100 (Conv2D)         (None, 32, 32, 32)        896
#
#  conv2d_101 (Conv2D)         (None, 32, 32, 64)        18496
#
#  conv2d_102 (Conv2D)         (None, 32, 32, 128)       73856
#
#  batch_normalization_137 (B  (None, 32, 32, 128)       512
#  atchNormalization)
#
#  activation_111 (Activation  (None, 32, 32, 128)       0
#  )
#
#  depthwise_conv2d_55 (Depth  (None, 32, 32, 128)       1280
#  wiseConv2D)
#
#  batch_normalization_138 (B  (None, 32, 32, 128)       512
#  atchNormalization)
#
#  activation_112 (Activation  (None, 32, 32, 128)       0
#  )
#
#  conv2d_103 (Conv2D)         (None, 32, 32, 24)        3096
#
#  batch_normalization_139 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_113 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_43 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_56 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_140 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_114 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_104 (Conv2D)         (None, 16, 16, 48)        1200
#
#  batch_normalization_141 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_115 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_44 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_57 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_142 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_116 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_105 (Conv2D)         (None, 8, 8, 96)          4704
#
#  batch_normalization_143 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_117 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_58 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_144 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_118 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_106 (Conv2D)         (None, 8, 8, 192)         18624
#
#  batch_normalization_145 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_119 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_45 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_59 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_146 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_120 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_107 (Conv2D)         (None, 4, 4, 96)          18528
#
#  batch_normalization_147 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_121 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_60 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_148 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_122 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_108 (Conv2D)         (None, 4, 4, 192)         18624
#
#  batch_normalization_149 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_123 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_46 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  depthwise_conv2d_61 (Depth  (None, 2, 2, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_150 (B  (None, 2, 2, 192)         768
#  atchNormalization)
#
#  activation_124 (Activation  (None, 2, 2, 192)         0
#  )
#
#  conv2d_109 (Conv2D)         (None, 2, 2, 96)          18528
#
#  batch_normalization_151 (B  (None, 2, 2, 96)          384
#  atchNormalization)
#
#  activation_125 (Activation  (None, 2, 2, 96)          0
#  )
#
#  depthwise_conv2d_62 (Depth  (None, 2, 2, 96)          960
#  wiseConv2D)
#
#  batch_normalization_152 (B  (None, 2, 2, 96)          384
#  atchNormalization)
#
#  activation_126 (Activation  (None, 2, 2, 96)          0
#  )
#
#  conv2d_110 (Conv2D)         (None, 2, 2, 192)         18624
#
#  batch_normalization_153 (B  (None, 2, 2, 192)         768
#  atchNormalization)
#
#  activation_127 (Activation  (None, 2, 2, 192)         0
#  )
#
#  max_pooling2d_47 (MaxPooli  (None, 1, 1, 192)         0
#  ng2D)
#
#  dense_12 (Dense)            (None, 1, 1, 500)         96500
#
#  flatten_9 (Flatten)         (None, 500)               0
#
#  dropout_11 (Dropout)        (None, 500)               0
#
#  dense_13 (Dense)            (None, 10)                5010
#
# =================================================================
# Total params: 313150 (1.19 MB)
# Trainable params: 309278 (1.18 MB)
# Non-trainable params: 3872 (15.12 KB)
# _________________________________________________________________
# None
# Epoch 1/100
# 834/834 [==============================] - 119s 142ms/step - loss: 1.8586 - accuracy: 0.3092 - val_loss: 1.7589 - val_accuracy: 0.3586 - lr: 0.0010
# Epoch 2/100
# 834/834 [==============================] - 116s 139ms/step - loss: 1.5487 - accuracy: 0.4281 - val_loss: 1.5617 - val_accuracy: 0.4209 - lr: 0.0010
# Epoch 3/100
# 834/834 [==============================] - 116s 139ms/step - loss: 1.4015 - accuracy: 0.4845 - val_loss: 1.4332 - val_accuracy: 0.4765 - lr: 0.0010
# Epoch 4/100
# 834/834 [==============================] - 117s 140ms/step - loss: 1.2805 - accuracy: 0.5346 - val_loss: 1.4097 - val_accuracy: 0.4908 - lr: 0.0010
# Epoch 5/100
# 834/834 [==============================] - 116s 139ms/step - loss: 1.1833 - accuracy: 0.5721 - val_loss: 1.2992 - val_accuracy: 0.5444 - lr: 0.0010
# Epoch 6/100
# 834/834 [==============================] - 117s 140ms/step - loss: 1.0926 - accuracy: 0.6072 - val_loss: 1.2440 - val_accuracy: 0.5561 - lr: 0.0010
# Epoch 7/100
# 834/834 [==============================] - 116s 139ms/step - loss: 1.0287 - accuracy: 0.6320 - val_loss: 1.1885 - val_accuracy: 0.5767 - lr: 0.0010
# Epoch 8/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.9695 - accuracy: 0.6526 - val_loss: 1.0385 - val_accuracy: 0.6347 - lr: 0.0010
# Epoch 9/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.9235 - accuracy: 0.6705 - val_loss: 1.0509 - val_accuracy: 0.6335 - lr: 0.0010
# Epoch 10/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.8755 - accuracy: 0.6892 - val_loss: 0.9872 - val_accuracy: 0.6536 - lr: 0.0010
# Epoch 11/100
# 834/834 [==============================] - 118s 141ms/step - loss: 0.8348 - accuracy: 0.7033 - val_loss: 0.9853 - val_accuracy: 0.6540 - lr: 0.0010
# Epoch 12/100
# 834/834 [==============================] - 118s 141ms/step - loss: 0.7984 - accuracy: 0.7174 - val_loss: 1.0478 - val_accuracy: 0.6400 - lr: 0.0010
# Epoch 13/100
# 834/834 [==============================] - 118s 141ms/step - loss: 0.7674 - accuracy: 0.7274 - val_loss: 1.0803 - val_accuracy: 0.6317 - lr: 0.0010
# Epoch 14/100
# 834/834 [==============================] - 120s 144ms/step - loss: 0.7327 - accuracy: 0.7394 - val_loss: 0.9547 - val_accuracy: 0.6661 - lr: 0.0010
# Epoch 15/100
# 834/834 [==============================] - 118s 142ms/step - loss: 0.7012 - accuracy: 0.7533 - val_loss: 0.9517 - val_accuracy: 0.6689 - lr: 0.0010
# Epoch 16/100
# 834/834 [==============================] - 119s 143ms/step - loss: 0.6739 - accuracy: 0.7629 - val_loss: 0.9226 - val_accuracy: 0.6762 - lr: 0.0010
# Epoch 17/100
# 834/834 [==============================] - 117s 140ms/step - loss: 0.6443 - accuracy: 0.7720 - val_loss: 0.9201 - val_accuracy: 0.6857 - lr: 0.0010
# Epoch 18/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.6224 - accuracy: 0.7804 - val_loss: 0.8767 - val_accuracy: 0.6996 - lr: 0.0010
# Epoch 19/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.5944 - accuracy: 0.7912 - val_loss: 0.9061 - val_accuracy: 0.6974 - lr: 0.0010
# Epoch 20/100
# 834/834 [==============================] - 117s 140ms/step - loss: 0.5800 - accuracy: 0.7948 - val_loss: 0.8774 - val_accuracy: 0.7034 - lr: 0.0010
# Epoch 21/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.5529 - accuracy: 0.8059 - val_loss: 0.9031 - val_accuracy: 0.7028 - lr: 0.0010
# Epoch 22/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.5398 - accuracy: 0.8090 - val_loss: 0.8958 - val_accuracy: 0.7020 - lr: 0.0010
# Epoch 23/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.5170 - accuracy: 0.8173 - val_loss: 0.8823 - val_accuracy: 0.7056 - lr: 0.0010
# Epoch 24/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.4948 - accuracy: 0.8241 - val_loss: 0.9276 - val_accuracy: 0.6882 - lr: 0.0010
# Epoch 25/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.4834 - accuracy: 0.8289 - val_loss: 0.8964 - val_accuracy: 0.7021 - lr: 0.0010
# Epoch 26/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.4604 - accuracy: 0.8385 - val_loss: 0.9731 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 27/100
# 834/834 [==============================] - 117s 140ms/step - loss: 0.4438 - accuracy: 0.8427 - val_loss: 0.9348 - val_accuracy: 0.7017 - lr: 0.0010
# Epoch 28/100
# 834/834 [==============================] - 118s 141ms/step - loss: 0.4259 - accuracy: 0.8485 - val_loss: 1.0034 - val_accuracy: 0.6901 - lr: 0.0010
# Epoch 29/100
# 834/834 [==============================] - 118s 141ms/step - loss: 0.4206 - accuracy: 0.8503 - val_loss: 0.9204 - val_accuracy: 0.7129 - lr: 0.0010
# Epoch 30/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.3985 - accuracy: 0.8569 - val_loss: 0.9238 - val_accuracy: 0.7102 - lr: 0.0010
# Epoch 31/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.3878 - accuracy: 0.8627 - val_loss: 0.9569 - val_accuracy: 0.7057 - lr: 0.0010
# Epoch 32/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.3704 - accuracy: 0.8697 - val_loss: 0.9446 - val_accuracy: 0.7169 - lr: 0.0010
# Epoch 33/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.3622 - accuracy: 0.8705 - val_loss: 0.9663 - val_accuracy: 0.7144 - lr: 0.0010
# Epoch 34/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.3477 - accuracy: 0.8761 - val_loss: 0.9596 - val_accuracy: 0.7156 - lr: 0.0010
# Epoch 35/100
# 834/834 [==============================] - 115s 138ms/step - loss: 0.3393 - accuracy: 0.8807 - val_loss: 1.0354 - val_accuracy: 0.7028 - lr: 0.0010
# Epoch 36/100
# 834/834 [==============================] - 116s 140ms/step - loss: 0.3279 - accuracy: 0.8838 - val_loss: 1.0052 - val_accuracy: 0.7116 - lr: 0.0010
# Epoch 37/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.3083 - accuracy: 0.8907 - val_loss: 1.0477 - val_accuracy: 0.7037 - lr: 0.0010
# Epoch 38/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.3014 - accuracy: 0.8922 - val_loss: 1.0210 - val_accuracy: 0.7135 - lr: 0.0010
# Epoch 39/100
# 834/834 [==============================] - 116s 139ms/step - loss: 0.2879 - accuracy: 0.8988 - val_loss: 1.0296 - val_accuracy: 0.7098 - lr: 0.0010
# Epoch 40/100
# 834/834 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.8978
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 834/834 [==============================] - 120s 144ms/step - loss: 0.2840 - accuracy: 0.8978 - val_loss: 1.1020 - val_accuracy: 0.6991 - lr: 0.0010
# Epoch 40: early stopping
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 32, 32, 3)]       0
#
#  conv2d_100 (Conv2D)         (None, 32, 32, 32)        896
#
#  conv2d_101 (Conv2D)         (None, 32, 32, 64)        18496
#
#  conv2d_102 (Conv2D)         (None, 32, 32, 128)       73856
#
#  batch_normalization_137 (B  (None, 32, 32, 128)       512
#  atchNormalization)
#
#  activation_111 (Activation  (None, 32, 32, 128)       0
#  )
#
#  depthwise_conv2d_55 (Depth  (None, 32, 32, 128)       1280
#  wiseConv2D)
#
#  batch_normalization_138 (B  (None, 32, 32, 128)       512
#  atchNormalization)
#
#  activation_112 (Activation  (None, 32, 32, 128)       0
#  )
#
#  conv2d_103 (Conv2D)         (None, 32, 32, 24)        3096
#
#  batch_normalization_139 (B  (None, 32, 32, 24)        96
#  atchNormalization)
#
#  activation_113 (Activation  (None, 32, 32, 24)        0
#  )
#
#  max_pooling2d_43 (MaxPooli  (None, 16, 16, 24)        0
#  ng2D)
#
#  depthwise_conv2d_56 (Depth  (None, 16, 16, 24)        240
#  wiseConv2D)
#
#  batch_normalization_140 (B  (None, 16, 16, 24)        96
#  atchNormalization)
#
#  activation_114 (Activation  (None, 16, 16, 24)        0
#  )
#
#  conv2d_104 (Conv2D)         (None, 16, 16, 48)        1200
#
#  batch_normalization_141 (B  (None, 16, 16, 48)        192
#  atchNormalization)
#
#  activation_115 (Activation  (None, 16, 16, 48)        0
#  )
#
#  max_pooling2d_44 (MaxPooli  (None, 8, 8, 48)          0
#  ng2D)
#
#  depthwise_conv2d_57 (Depth  (None, 8, 8, 48)          480
#  wiseConv2D)
#
#  batch_normalization_142 (B  (None, 8, 8, 48)          192
#  atchNormalization)
#
#  activation_116 (Activation  (None, 8, 8, 48)          0
#  )
#
#  conv2d_105 (Conv2D)         (None, 8, 8, 96)          4704
#
#  batch_normalization_143 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_117 (Activation  (None, 8, 8, 96)          0
#  )
#
#  depthwise_conv2d_58 (Depth  (None, 8, 8, 96)          960
#  wiseConv2D)
#
#  batch_normalization_144 (B  (None, 8, 8, 96)          384
#  atchNormalization)
#
#  activation_118 (Activation  (None, 8, 8, 96)          0
#  )
#
#  conv2d_106 (Conv2D)         (None, 8, 8, 192)         18624
#
#  batch_normalization_145 (B  (None, 8, 8, 192)         768
#  atchNormalization)
#
#  activation_119 (Activation  (None, 8, 8, 192)         0
#  )
#
#  max_pooling2d_45 (MaxPooli  (None, 4, 4, 192)         0
#  ng2D)
#
#  depthwise_conv2d_59 (Depth  (None, 4, 4, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_146 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_120 (Activation  (None, 4, 4, 192)         0
#  )
#
#  conv2d_107 (Conv2D)         (None, 4, 4, 96)          18528
#
#  batch_normalization_147 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_121 (Activation  (None, 4, 4, 96)          0
#  )
#
#  depthwise_conv2d_60 (Depth  (None, 4, 4, 96)          960
#  wiseConv2D)
#
#  batch_normalization_148 (B  (None, 4, 4, 96)          384
#  atchNormalization)
#
#  activation_122 (Activation  (None, 4, 4, 96)          0
#  )
#
#  conv2d_108 (Conv2D)         (None, 4, 4, 192)         18624
#
#  batch_normalization_149 (B  (None, 4, 4, 192)         768
#  atchNormalization)
#
#  activation_123 (Activation  (None, 4, 4, 192)         0
#  )
#
#  max_pooling2d_46 (MaxPooli  (None, 2, 2, 192)         0
#  ng2D)
#
#  depthwise_conv2d_61 (Depth  (None, 2, 2, 192)         1920
#  wiseConv2D)
#
#  batch_normalization_150 (B  (None, 2, 2, 192)         768
#  atchNormalization)
#
#  activation_124 (Activation  (None, 2, 2, 192)         0
#  )
#
#  conv2d_109 (Conv2D)         (None, 2, 2, 96)          18528
#
#  batch_normalization_151 (B  (None, 2, 2, 96)          384
#  atchNormalization)
#
#  activation_125 (Activation  (None, 2, 2, 96)          0
#  )
#
#  depthwise_conv2d_62 (Depth  (None, 2, 2, 96)          960
#  wiseConv2D)
#
#  batch_normalization_152 (B  (None, 2, 2, 96)          384
#  atchNormalization)
#
#  activation_126 (Activation  (None, 2, 2, 96)          0
#  )
#
#  conv2d_110 (Conv2D)         (None, 2, 2, 192)         18624
#
#  batch_normalization_153 (B  (None, 2, 2, 192)         768
#  atchNormalization)
#
#  activation_127 (Activation  (None, 2, 2, 192)         0
#  )
#
#  max_pooling2d_47 (MaxPooli  (None, 1, 1, 192)         0
#  ng2D)
#
#  dense_12 (Dense)            (None, 1, 1, 500)         96500
#
#  flatten_9 (Flatten)         (None, 500)               0
#
#  dropout_11 (Dropout)        (None, 500)               0
#
#  dense_13 (Dense)            (None, 10)                5010
#
# =================================================================
# Total params: 313150 (1.19 MB)
# Trainable params: 309278 (1.18 MB)
# Non-trainable params: 3872 (15.12 KB)
# _________________________________________________________________
# None
# > 69.450
